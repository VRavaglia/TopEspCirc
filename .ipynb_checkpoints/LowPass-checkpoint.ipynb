# %%
import math
import numpy as np
import matplotlib.pyplot as plt

import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging()

from PySpice.Plot.BodeDiagram import bode_diagram
from PySpice.Spice.Netlist import Circuit
from PySpice.Unit import *

# %%
def get_break_freq(gain, freq):
    mx = np.max(gain)
    for  i in range(1, len(gain)):
        if(gain[i] <= mx -3):
            return float(freq[i-1])
    return -1

# %%
def compute_fitness(R, C, target):
    circuit = Circuit('Low-Pass RC Filter')
    circuit.SinusoidalVoltageSource('input', 'inp', circuit.gnd, amplitude=1@u_V)
    R1 = circuit.R(1, 'inp', 'out', R@u_kΩ)
    C1 = circuit.C(1, 'out', circuit.gnd, C@u_uF)

    simulator = circuit.simulator(temperature=25, nominal_temperature=25)
    analysis = simulator.ac(start_frequency=1@u_Hz, stop_frequency=1@u_MHz, number_of_points=10,  variation='dec')
    
    break_frequency = get_break_freq(20*np.log10(np.absolute(analysis.out)), analysis.frequency)
    
    return 1/(1 + np.abs(break_frequency - target))

# %%
def SGA (Xs, gens, k, mu, max_inc, target, n_params, limits):
    parents = np.zeros((k, n_params))
    p1 = np.zeros((n_params, 1))
    p2 = np.zeros((n_params, 1))
    Jhist = np.zeros((gens, 1))
    scores = np.zeros((mu, 1))
    for gen in range(0, gens):
        # Pontuacao  
        for i in range(0, mu):
            scores[i] = compute_fitness(Xs[i, 0], Xs[i, 1], target)
        
        minIdx = np.argmin(scores)
        Jhist[gen] = scores[minIdx]
        
        # Selecao dos Pais
        topIdx = np.sort(scores)

        for i in range(0, k):
            for j in range(0, n_params):
                parents[i, j] = Xs[topIdx[i], j]
        
        # Crossover
        for i in range(0, mu):
            r1 = np.random.randint(0, k)
            r2 = np.random.randint(0, k)
            for j in range(0, n_params):
                Xs[i, j] = parents[r1, j]/2 + parents[r2, j]/2
        
        # Mutacao
        for i in range(0, mu):
            for j in range(0, n_params):
                if np.random.rand() <= taxaMut:
                    increment = np.random.uniform(-max_inc, max_inc)
                    Xs[i, j] += increment
                    if Xs[i, j] < limits[0] or Xs[i, j] > limits[1]:
                        Xs[i, j] -= 2*increment
        
    # Pontuacao
    minIdx = np.argmin(scores)
    return scores[minIdx], Xs[minIdx, :], Jhist

# %%
runs = 1
mu = 3
gens = 10
k = 2
taxa_mut = 0.3
n_params = 2
max_inc = 0.5
target = 1e3
n_params = 2
limits = [0.1, 10]

allX = np.zeros((runs, n_params))
allS = np.zeros((runs, 1))
allJ = np.zeros((runs, gens))

for j in range(0, runs):
    np.random.seed(j)

    Xs = np.random.uniform(limits[0],limits[1], (mu, n_params))
     
    minS, minX, Jhist = SGA(Xs, gens, k, mu, max_inc, target, n_params, limits)
    allX[j, :] = minX
    allS[J] = minS
    allJ[j, :] = Jhist
# Out:
# 2022-07-11 11:28:08,557 - PySpice.Probe.WaveForm.WaveForm - Unit.WARNING - Should be unit less
# 2022-07-11 11:28:08,561 - PySpice.Probe.WaveForm.WaveForm - Unit.WARNING - Should be unit less
# 2022-07-11 11:28:08,562 - PySpice.Probe.WaveForm.WaveForm - Unit.WARNING - Should be unit less
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-9e1bd4d49843> in <module>
#      19     Xs = np.random.uniform(limits[0],limits[1], (mu, n_params))
#      20
# ---> 21     minS, minX, Jhist = SGA(Xs, gens, k, mu, max_inc, target, n_params, limits)
#      22     allX[j, :] = minX
#      23     allS[J] = minS
#
# <ipython-input-6-18d94f4c6721> in SGA(Xs, gens, k, mu, max_inc, target, n_params, limits)
#      18         for i in range(0, k):
#      19             for j in range(0, n_params):
# ---> 20                 parents[i, j] = Xs[topIdx[i], j]
#      21
#      22         # Crossover
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
bestR = 1
bestC = 1

circuit = Circuit('Low-Pass RC Filter')
circuit.SinusoidalVoltageSource('input', 'inp', circuit.gnd, amplitude=1@u_V)
R1 = circuit.R(1, 'inp', 'out', bestR@u_kΩ)
C1 = circuit.C(1, 'out', circuit.gnd, bestC@u_uF)

simulator = circuit.simulator(temperature=25, nominal_temperature=25)
analysis = simulator.ac(start_frequency=1@u_Hz, stop_frequency=1@u_MHz, number_of_points=10,  variation='dec')

break_frequency = get_break_freq(20*np.log10(np.absolute(analysis.out)), analysis.frequency)

# %%
figure, axes = plt.subplots(2, figsize=(20, 10))
plt.title("Bode Diagram of a Low-Pass RC Filter")
bode_diagram(axes=axes,
             frequency=analysis.frequency,
             gain=20*np.log10(np.absolute(analysis.out)),
             phase=np.angle(analysis.out, deg=False),
             marker='.',
             color='blue',
             linestyle='-',
)
for ax in axes:
    ax.axvline(x=break_frequency, color='red')

plt.tight_layout()
print("Break frequency = {:.1f} Hz".format(break_frequency))
print("Best Fitness = ", str(compute_fitness(bestR, bestC, target)))
plt.show()
# Out:
# c:\users\victo\appdata\local\programs\python\python38\lib\site-packages\PySpice\Plot\BodeDiagram.py:36: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   axe.semilogx(frequency, gain, basex=10, **kwargs)
# c:\users\victo\appdata\local\programs\python\python38\lib\site-packages\PySpice\Plot\BodeDiagram.py:46: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   axe.semilogx(frequency, phase, basex=10, **kwargs)
# Break frequency = 100.0 Hz
# Best Fitness =  0.016666666666666705
